# %%
import data_visualization
data_visualization.plot_googleMap()

# %%
pip install bokeh
# Out:
# Requirement already satisfied: bokeh in c:\users\tanmo\onedrive - dalhousie university\phd tanmoy das\multiobjective-optimization-of-resource-allocation\multiobjective_location_allocation_env\lib\site-packages (3.1.0)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: Jinja2>=2.9 in c:\users\tanmo\onedrive - dalhousie university\phd tanmoy das\multiobjective-optimization-of-resource-allocation\multiobjective_location_allocation_env\lib\site-packages (from bokeh) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\tanmo\onedrive - dalhousie university\phd tanmoy das\multiobjective-optimization-of-resource-allocation\multiobjective_location_allocation_env\lib\site-packages (from bokeh) (1.0.7)
# Requirement already satisfied: numpy>=1.16 in c:\users\tanmo\onedrive - dalhousie university\phd tanmoy das\multiobjective-optimization-of-resource-allocation\multiobjective_location_allocation_env\lib\site-packages (from bokeh) (1.24.2)
# Requirement already satisfied: packaging>=16.8 in c:\users\tanmo\onedrive - dalhousie university\phd tanmoy das\multiobjective-optimization-of-resource-allocation\multiobjective_location_allocation_env\lib\site-packages (from bokeh) (23.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\tanmo\onedrive - dalhousie university\phd tanmoy das\multiobjective-optimization-of-resource-allocation\multiobjective_location_allocation_env\lib\site-packages (from bokeh) (1.5.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\tanmo\onedrive - dalhousie university\phd tanmoy das\multiobjective-optimization-of-resource-allocation\multiobjective_location_allocation_env\lib\site-packages (from bokeh) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\tanmo\onedrive - dalhousie university\phd tanmoy das\multiobjective-optimization-of-resource-allocation\multiobjective_location_allocation_env\lib\site-packages (from bokeh) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\tanmo\onedrive - dalhousie university\phd tanmoy das\multiobjective-optimization-of-resource-allocation\multiobjective_location_allocation_env\lib\site-packages (from bokeh) (6.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\tanmo\onedrive - dalhousie university\phd tanmoy das\multiobjective-optimization-of-resource-allocation\multiobjective_location_allocation_env\lib\site-packages (from bokeh) (2023.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tanmo\onedrive - dalhousie university\phd tanmoy das\multiobjective-optimization-of-resource-allocation\multiobjective_location_allocation_env\lib\site-packages (from Jinja2>=2.9->bokeh) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\tanmo\onedrive - dalhousie university\phd tanmoy das\multiobjective-optimization-of-resource-allocation\multiobjective_location_allocation_env\lib\site-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tanmo\onedrive - dalhousie university\phd tanmoy das\multiobjective-optimization-of-resource-allocation\multiobjective_location_allocation_env\lib\site-packages (from pandas>=1.2->bokeh) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\tanmo\onedrive - dalhousie university\phd tanmoy das\multiobjective-optimization-of-resource-allocation\multiobjective_location_allocation_env\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.2->bokeh) (1.16.0)

# %%
import gmaps
gmaps.configure(api_key='AIzaSyAyRAMSfG6ic9oYV9bemRkn2sYqOh8VQSE')
from bokeh.io import output_notebook
output_notebook()
#bokeh_width, bokeh_height = 500, 400
import os
api_key = 'AIzaSyAyRAMSfG6ic9oYV9bemRkn2sYqOh8VQSE'  # os.environ['AIzaSyAyRAMSfG6ic9oYV9bemRkn2sYqOh8VQSE']
from bokeh.io import show
from bokeh.plotting import gmap
from bokeh.models import GMapOptions

lat, lon = 46.2437, 6.0251

def plot(lat, lng, zoom=1, map_type='terrain'):
    gmap_options = GMapOptions(lat=lat, lng=lng, map_type=map_type, zoom=zoom)
    p = gmap(api_key, gmap_options, title='Google Map for Arctic Canada')     #,width=bokeh_width, height=bokeh_height)
    show(p)
    return p
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1129">Loading BokehJS ...</span>
#     </div>

# %%
p = plot(lat, lon)
# Out:
#   <div id="63b9ac3b-f2af-486c-bcf1-e407bb16dd80" data-root-id="p1131" style="display: contents;"></div>

# %%
import gmaps
gmaps.configure(api_key='AIzaSyAyRAMSfG6ic9oYV9bemRkn2sYqOh8VQSE')
from bokeh.io import output_notebook
from bokeh.io import show
from bokeh.plotting import figure, gmap
from bokeh.models import GMapOptions

bokeh_width, bokeh_height =500,400
api_key = 'AIzaSyAyRAMSfG6ic9oYV9bemRkn2sYqOh8VQSE'  # os.environ['AIzaSyAyRAMSfG6ic9oYV9bemRkn2sYqOh8VQSE']
# %%
output_notebook()
figure(height=300, width=600) # , x_range=(-100,-70), y_range=(50, 70))
def plot(lat, lng, zoom=1, map_type='roadmap'):
    gmap_options = GMapOptions(lat=lat, lng=lng,
                               map_type=map_type, zoom=zoom)
    p = gmap(api_key, gmap_options, title='Google Map',
             width=bokeh_width, height=bokeh_height)
    show(p)
    return p

p = plot(46.2437, 6.0251)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1860">Loading BokehJS ...</span>
#     </div>
#   <div id="4bf570e0-0809-4640-b6ca-df6b88271d74" data-root-id="p1908" style="display: contents;"></div>

# %% [markdown]
# # Objective 1 vs 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
data_obj = pd.read_excel('Outputs/obj1vsobj2.xlsx')
data_obj = data_obj.iloc[0:20,0:2]
data_obj
# Out:
#     Max Coverage       Min Cost
# 0      95.626462  825541.685783
# 1      95.626462  825541.685783
# 2      95.626462  825541.685783
# 3      95.626462  825541.685783
# 4      95.626462  825541.685783
# 5      95.626462  825541.685783
# 6      95.626462  825541.685783
# 7      95.626462  941168.042330
# 8      95.626462  941168.042330
# 9      95.626462  941168.042330
# 10     90.893077  931561.871301
# 11     69.887054  890801.070381
# 12     69.887054  890801.070381
# 13     69.887054  890801.070381
# 14     69.887054  890801.070381
# 15     69.887054  890801.070381
# 16     69.887054  890801.070381
# 17     61.757385  788581.647838
# 18     22.503862  368113.214924
# 19     21.750185  312360.402860

# %%
plt.scatter(data_obj['Max Coverage'], data_obj['Min Cost'])
plt.xlabel("Max Coverage")
plt.ylabel("Min Cost")
#plt.axis("off")
plt.show()
